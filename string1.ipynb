# %%
class car:
    brand = "BMW"
    color = "white"

car1 = car()
print(car1.brand)
print(car1.color)
# Out:
# BMW
# white

# %%
class Student:
    def __init__(self,name,age):
      self.name = name
      self.age = age

s1 = Student("manusha",20)
print(s1.name)
# Out:
# manusha

# %%
 s1 = student("Manusha",20)
 print(s1.name)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 s1 = student("Manusha",20)
#       2 print(s1.name)
#
# NameError: name 'student' is not defined

# %%
class Student:
    def __init__(self,name,age):
       self.name = name
       self.age = age

s1 = Student("deekshitha",16)
print(s1.name)
# Out:
# deekshitha

# %%
class Student:
    def __init__(self,name,age):
        self.name = name 
        self.age = age

s1 = Student("rashimitha",14)
print(s1.name)
# Out:
# rashimitha

# %%
name = "Manusha"
print(name)
email= "gadddimanushagmail.com"
print(email)
# Out:
# Manusha
# gadddimanushagmail.com

# %%
city="india"
print(city[1])
# Out:
# n

# %%
city="chennai"
print(city[3])
# Out:
# n

# %%
city="kerala"
print(city[-2])
# Out:
# l

# %%
name="manusha"
print(name[1:6])
# Out:
# anush

# %%
print("Hello"*5)
# Out:
# HelloHelloHelloHelloHello

# %%
first="manusha"
second="yadav"

# %%
name="manusha"
print(name.upper())
# Out:
# MANUSHA

# %%
name="MANUSHA"
print(name.lower())
# Out:
# manusha

# %%
s="I like java"
print(s.replace("java","python"))
# Out:
# I like python
