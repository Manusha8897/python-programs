# %%
name = [5,7,9,]
it=iter(name)
print(next(it))
print(next(it))
print(next(it))
# Out:
# 5
# 7
# 9

# %%
name = ["apple","banana","grapes"]
it =iter(name)
print(next(it))
print(next(it))
print(next(it))
# Out:
# apple
# banana
# grapes
