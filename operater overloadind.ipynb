# %%
print(10+20)
print("Manusha" + "yadav")
# Out:
# 30
# Manushayadav

# %%
print('manusha'*3)
# Out:
# manushamanushamanusha

# %%
class Student:
    def __init__(self, marks):
        self.marks=marks

    def __add__(self,other):
        return self.marks+other.marks
s1=Student(80)
s2=Student(75)
print(s1+s2)
# Out:
# 155
