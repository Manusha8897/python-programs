# %%
s="anything something"
print(s.find("something"))
# Out:
# 9

# %%
name=input("Enter the name:")
print("welcome",name)
# Out:
# Enter the name: manusha
# welcome manusha

# %%
p="python"
print(p[::-1])
# Out:
# nohtyp

# %%
first="manusha"
second="yadav"
print(first+ "" +second)
# Out:
# manushayadav

# %%
name="manusha"
def greet():
    print("Hello", name)
greet()
# Out:
# Hello manusha

# %%
name="geetha"
def greet():
    print("Hi",name)
greet()
# Out:
# Hi geetha

# %%
def add(a,b,c=0):
    return a+b+c
print(add(10,20))
print(add(10,20,30))
# Out:
# 30
# 60

# %%
def multiple(a,b,c=0):
     return a*b*c
print(multiple(10,20))
print(multiple(10,20,30))
# Out:
# 0
# 6000

# %%
def add(*numbers):
    print(sum(numbers))
add(10,20)
add(10,20,30)
add(10,20,30,40)
# Out:
# 30
# 60
# 100

# %%
def student(*marks):
    print(total(marks))
add(30,50)
add(34,56,76)
add(29,76,59,30)
add(30,87,67,56,45)
# Out:
# 80
# 166
# 194
# 285
